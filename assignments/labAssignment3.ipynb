# %% [markdown]
# <a href="https://colab.research.google.com/github/informloulie/music-computing/blob/main/assignments/labAssignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pylab as plt
import librosa.display
import IPython.display
import librosa

#import audio files
# !git clone https://github.com/jcdevaney/musicComputing2026.git
# Out:
# Cloning into 'musicComputing2025'...
# remote: Enumerating objects: 117, done.
# remote: Counting objects: 100% (117/117), done.
# remote: Compressing objects: 100% (105/105), done.
# remote: Total 117 (delta 52), reused 18 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (117/117), 16.84 MiB | 9.40 MiB/s, done.
# Resolving deltas: 100% (52/52), done.

# %%
def plotAudio2(sig,sampleRate,title):

    # add in the code from Assignment 2
    plt.figure(figsize=(15, 5)) # Create a new figure
    librosa.display.waveshow(sig, sr=sampleRate) # Plot the waveform
    plt.title(title) # Set the title
    plt.xlabel("Time") # Add x-axis label
    plt.ylabel("Amplitude") # Add y-axis label
    plt.show() # Display the plot

# %%
def plotAudioFreqDomain(sig,sr,title,winSize,specType):

    # create a normalized spectrogram
    librosa.amplitude_to_db(np.abs(librosa.stft(sig,n_fft=256)), ref=np.max)

    # this includes several function calls
    # first create a basic specgrogram with librosa.stft() with the default window size (2048)
    # then make all of values in the spectrogram positive with np.abs()
    # then scale the spectogram to be in decibels, so it better reflects how we hear librosa.amplitude_to_db()

    # display the normalized spectrogram with a log frequency scale

# %%
def plotAudioFunc(sig,sr,title,winSize,specType):

    #call plotAudio2
    defplotAudio2()
    #call plotAudioFreqDomain
    defplotAudioFreqDomain()

# %%
sig , sr = librosa.load('musicComputing2026/audioFiles/avm.wav')

# %%
title = 'Ave Maria'
winSize = 2048
specType = 'linear'

#call plotAudioFunc

# %%
title = 'Ave Maria'
winSize = 2048
specType = 'log'

#call plotAudioFunc

# %%
title = 'Ave Maria'
winSize = 256
specType = 'linear'

#call plotAudioFunc

# %%
title = 'Ave Maria'
winSize = 256
specType = 'log'

# call plotAudioFunc
